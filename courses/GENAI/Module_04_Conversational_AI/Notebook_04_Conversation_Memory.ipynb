# %% [markdown]
# # **Conversation Memory Management**
# # **Introduction**
# This notebook focuses on managing conversation memory effectively, including handling memory constraints, implementing memory policies, and managing conversation history.
#
# ## **Basic Memory Management**
# **Let's start with basic conversation memory handling:**

# %%
from swarmauri.llms.concrete.GroqModel import GroqModel
from swarmauri.messages.concrete import SystemMessage, HumanMessage, AgentMessage
from swarmauri.conversations.concrete.SessionCacheConversation import SessionCacheConversation
import os
from dotenv import load_dotenv

# %% [markdown]
# **Initialize the Groq model**

# %%
load_dotenv()
api_key = os.getenv("GROQ_API_KEY")
llm = GroqModel(api_key=api_key)

# %% [markdown]
# ## **LLM Memory Setup**
#  **Create a conversation with limited memory**

# %%
# Create conversation with memory limit
conversation = SessionCacheConversation(
    system_context=SystemMessage(content="You are a knowledgeable research assistant"),
    max_size=4
)

# %% [markdown]
# **Add more messages than the memory limit**

# %%
messages = [
    ("What is machine learning?", "Machine learning is..."),
    ("What about neural networks?", "Neural networks are..."),
    ("How do they work?", "They process information by..."),
    ("Can you give an example?", "Consider image recognition...")
]

# %%
for question, answer in messages:
    conversation.add_message(HumanMessage(content=question))
    conversation.add_message(AgentMessage(content=answer))

print("Current Memory Content:")
for msg in conversation.history:
    print(f"Type: {type(msg).__name__}, Content: {msg.content}")
# Out:
# Current Memory Content:
# Type: SystemMessage, Content: You are a knowledgeable research assistant
# Type: HumanMessage, Content: How do they work?
# Type: AgentMessage, Content: They process information by...
# Type: HumanMessage, Content: Can you give an example?
# Type: AgentMessage, Content: Consider image recognition...

# %% [markdown]
# ## **Memory-Aware Conversations**
#
#
# **Test memory retention with multiple questions**

# %%
# Test memory retention with multiple questions
research_questions = [
    "What is quantum computing?",
    "How does it differ from classical computing?",
    "What are qubits?",
    "What companies are working on quantum computers?",
    "What are the main challenges?"
]

# %%
for question in research_questions:
    conversation.add_message(HumanMessage(content=question))
    response = llm.predict(conversation)
    conversation.add_message(AgentMessage(content=response.get_last().content))
    
    print(f"\nQ: {question}")
    print(f"A: {response.get_last().content}")
    print("\nCurrent Memory Size:", len(conversation.history))
# Out:
# Q: What is quantum computing?
# A: **Quantum computing** is a new type of computing that harnesses the unique properties of quantum mechanics to perform computations. Unlike classical computers that use bits (0 or 1) to store information, quantum computers use **qubits**.
#
# **Qubits** can exist in a superposition of states, meaning they can be both 0 and 1 simultaneously. This allows quantum computers to perform parallel computations, exploring multiple possibilities simultaneously.
#
#
# **How it works:**
#
# - Quantum computers use **superposition** to store information in a qubit.
# - By manipulating the qubits through **quantum gates**, computations are performed.
# - The results are measured as probabilities of each possible outcome.
#
#
# **Applications of quantum computing:**
#
# **1. Drug discovery:**
# - Simulating complex molecular interactions for drug development
# - Identifying new targets for personalized medicine
#
# **2. Materials science:**
# - Designing new materials with improved properties
# - Understanding the behavior of materials at the atomic level
#
# **3. Optimization:**
# - Solving complex optimization problems in logistics, transportation, and finance
#
# **4. Machine learning:**
# - Enhancing the performance of machine learning algorithms
# - Developing new algorithms that can learn from incomplete or noisy data
#
# **5. Computational modeling:**
# - Simulating complex systems,
#
# Current Memory Size: 3
#
# Q: How does it differ from classical computing?
# A: **Classical computing:**
#
# - Uses bits (0 or 1) to store information
# - Processes information sequentially
# - Limited in its ability to handle complex problems
#
#
# **Quantum computing:**
#
# - Uses qubits (superposition of states)
# - Performs parallel computations
# - Can solve certain problems that are intractable for classical computers
#
#
# **Key differences:**
#
# **1. Parallelism:**
# - Quantum computers can perform multiple calculations simultaneously, while classical computers can only do one at a time.
#
# **2. Superposition:**
# - Qubits can exist in a state of both 0 and 1 simultaneously, allowing for parallel exploration of multiple possibilities.
#
# **3. Computational power:**
# - Quantum computers can solve certain complex problems that are intractable for classical computers.
#
# **4. Applications:**
# - Quantum computers have applications in fields such as drug discovery, materials science, and optimization.
#
# Current Memory Size: 3
#
# Q: What are qubits?
# A: **Qubits** are the basic units of information in quantum computing. They are quantum bits, which can exist in a superposition of states, meaning they can be in a state of both 0 and 1 simultaneously.
#
# **Properties of qubits:**
#
# - **Superposition:** Qubits can exist in a state of both 0 and 1 simultaneously.
# - **Entanglement:** Multiple qubits can be entangled, meaning their fates are intertwined even when separated.
# - **Non-locality:** Qubits can interact with each other instantly, regardless of the distance between them.
#
# **How qubits differ from bits:**
#
# - **Bits:** Represent information as either 0 or 1.
# - **Qubits:** Can exist in a superposition of states, allowing for both 0 and 1 simultaneously.
#
# **Applications of qubits:**
#
# - **Drug discovery:** Simulating molecular interactions to accelerate drug development.
# - **Materials science:** Designing new materials with desired properties.
# - **Optimization:** Solving complex optimization problems in logistics, transportation, and finance.
# - **Cryptography:** Developing quantum-resistant encryption algorithms.
#
# Current Memory Size: 3
#
# Q: What companies are working on quantum computers?
# A: **Major companies working on quantum computers:**
#
# **1. Google:**
# - Developing quantum processors and software.
# - Focuses on applied research in various sectors.
#
#
# **2. Amazon:**
# - Investing heavily in quantum hardware and software.
# - Working on applications in logistics, healthcare, and customer service.
#
#
# **3. IBM:**
# - Leading in hybrid cloud-based quantum computing.
# - Developing quantum hardware and software solutions.
#
#
# **4. Microsoft:**
# - Developing quantum computers and software.
# - Partnering with other companies on quantum applications.
#
#
# **5. Amazon Web Services (AWS):**
# - Offering quantum computing services through its Braket platform.
# - Partnering with startups to develop quantum applications.
#
#
# **6. Oracle:**
# - Developing quantum hardware and software.
# - Providing quantum computing services through its Quantum Cloud platform.
#
#
# **7. Lockheed Martin:**
# - Developing quantum sensors and control systems.
# - Working on applications in aerospace and defense.
#
#
# **8. Honeywell:**
# - Developing quantum sensors and control systems.
# - Working on applications in energy, transportation, and manufacturing.
#
#
# **9. QuantumScape:**
# - Developing silicon-based quantum processors.
# - Targeting high-performance computing and scientific applications.
#
#
#
#
# Current Memory Size: 3
#
# Q: What are the main challenges?
# A: **Main challenges in quantum computing:**
#
# **1. Hardware limitations:**
# - Quantum hardware is highly susceptible to errors and decoherence.
# - Limited coherence time and stability of qubits.
#
#
# **2. Error correction:**
# - Quantum computations are prone to errors due to quantum effects.
# - Developing effective error correction and fault-tolerance algorithms.
#
#
# **3. Scalability:**
# - Scaling up the number of qubits and operations without compromising coherence.
# - Designing scalable and efficient quantum algorithms.
#
#
# **4. Software Development:**
# - Lack of mature quantum programming languages and tools.
# - Need for specialized skills and knowledge to write quantum algorithms.
#
#
# **5. Cost:**
# - Development and deployment of quantum computers are highly expensive.
# - Limited availability of funding and investment opportunities.
#
#
# **6. Applications:**
# - Identifying and developing practical applications for quantum technology.
# - Overcoming technical barriers to achieve real-world impact.
#
#
# **7. Infrastructure:**
# - Establishing quantum-compatible data centers and networks.
# - Developing standards and protocols for quantum computing.
#
#
# **8. Security:**
# - Quantum computers pose potential security risks due to their ability to break current encryption methods.
# - Need to develop quantum-resistant cryptography.
#
# Current Memory Size: 3

# %% [markdown]
# ## **Memory Policy Implementation**
# **Example of implementing different memory policies:**

# %% [markdown]
# Create conversations with different memory policies

# %%
short_memory = SessionCacheConversation(
    system_context=SystemMessage(content="Short-term memory assistant"),
    max_size=2
)

long_memory = SessionCacheConversation(
    system_context=SystemMessage(content="Long-term memory assistant"),
    max_size=8
)

# %% [markdown]
#  **Add same conversation to both**

# %%
# Test question series
questions = [
    "Tell me about renewable energy",
    "What about solar power specifically?",
    "How do solar panels work?",
    "What's their efficiency?"
]

# %%
print("Short Memory Responses:")
for question in questions:
    short_memory.add_message(HumanMessage(content=question))
    response = llm.predict(short_memory)
    short_memory.add_message(AgentMessage(content=response.get_last().content))
    print(f"\nQ: {question}")
    print(f"A: {response.get_last().content}")
# Out:
# Short Memory Responses:
#
# Q: Tell me about renewable energy
# A: ## Renewable Energy
#
# Renewable energy sources are those that can be replenished naturally over short periods of time, unlike fossil fuels which are finite and contribute to climate change.
#
# **Types of renewable energy:**
#
# * **Solar energy:** Harnesses the power of the sun through technologies like solar panels and solar thermal systems.
# * **Wind energy:** Extracts kinetic energy from the wind using turbines to generate electricity.
# * **Hydropower:** Uses flowing water to generate electricity through dams or turbines.
# * **Geothermal energy:** Harnesses heat from the Earth's core through heat pumps and generators.
# * **Tidal energy:** Uses the rise and fall of tides to generate electricity.
# * **Bioenergy:** Generates energy from organic materials like plants and manure.
#
#
# **Advantages of renewable energy:**
#
# * **Sustainable:** Renewable sources are replenished naturally, ensuring long-term energy access.
# * **Clean:** Produces little to no greenhouse gas emissions, mitigating climate change.
# * **Cost-effective:** Technological advancements and government incentives are making renewable energy increasingly affordable.
# * **Job creation:** The transition towards renewable energy creates new job opportunities in manufacturing, installation, and maintenance.
#
#
# **Disadvantages of renewable energy:**
#
# * **Intermittent:** Sources like solar
#
# Q: What about solar power specifically?
# A: ## Short-Term Memory Assistant: Solar Power Key Points
#
# **1. Basic Concept:**
#
# * Solar power harnesses energy from the sun through photovoltaic cells or concentrating solar thermal systems.
# * It's a renewable and sustainable energy source, emitting no greenhouse gases.
#
#
# **2. Advantages:**
#
# * Abundant and readily available resource.
# * No fuel costs.
# * Low maintenance and operational costs in the long run.
# * Creates no pollution or noise.
# * Increases energy independence and security.
#
#
# **3. Disadvantages:**
#
# * Initial installation and storage costs can be high.
# * Output depends on weather conditions, impacting reliability in certain areas.
# * Large-scale implementation requires significant land area.
#
#
# **4. Applications:**
#
# * Grid-connected systems: Feed excess energy back to the grid.
# * Off-grid systems: Power remote locations without access to traditional energy.
# * Transportation: Electric vehicles powered by solar energy.
#
#
# **5. Current Trends:**
#
# * Advancements in storage technology are key to increasing solar energy's reliability.
# * Integration with other renewable energy sources like wind power is gaining traction.
# * Deployment in developing countries is rapidly increasing.
#
#
# **6. Future Potential:**
#
# * Solar energy is expected to become
#
# Q: How do solar panels work?
# A: **Solar panels work through the following steps:**
#
# **1. Photon absorption:**
#
# - Sunlight strikes the solar cells in the panel.
# - The photons in sunlight have energy that can excite electrons in atoms.
#
#
# **2. Electron excitation:**
#
# - The absorbed photons knock electrons out of their atoms, exciting them to a higher energy level.
#
#
# **3. Separation of charges:**
#
# - The excited electrons are separated from their positively charged atoms, creating a separation of charges.
#
#
# **4. Electron flow:**
#
# - The excited electrons are collected by metal electrodes at opposite ends of the solar cell.
# - The flow of electrons creates an electric current.
#
#
# **5. Direct current (DC) output:**
#
# - The direct current (DC) generated by the solar cells is then sent to an inverter.
#
#
# **6. Alternating current (AC) output:**
#
# - The inverter converts the DC electricity into alternating current (AC) electricity, which can be used to power devices or feed it back into the electrical grid.
#
# Q: What's their efficiency?
# A: **Short-term memory assistants have varying efficiency levels depending on the specific technology and implementation.**
#
# **General efficiency range:**
#
# * **Accuracy:** 85-95%
# * **Recall:** 70-90%
# * **Speed:** 50-100 queries per second
#
# **Factors affecting efficiency:**
#
# **1. Technology:**
# - Hardware specifications
# - Software architecture
# - Training data
#
# **2. Query complexity:**
# - Number of words in the query
# - Complexity of the concepts being queried
#
# **3. Context:**
# - Amount of relevant training data
# - Quality of training data
# - Real-time vs. offline processing
#
# **4. Memory limitations:**
# - Working memory size
# - Refresh rate of the memory
#
# **5. Training and personalization:**
# - Quality of training data
# - Number of training sessions
# - User-specific customization
#
# **Strengths of short-term memory assistants:**
#
# * **Fast retrieval:** Information is accessible quickly and efficiently.
# * **Context awareness:** Can remember relevant information from previous interactions.
# * **Continuous learning:** Can improve accuracy and efficiency over time.
# * **Personalization:** Can provide tailored responses based on user preferences and context.
#
# **Weaknesses of short

# %%
print("\nLong Memory Responses:")
for question in questions:
    long_memory.add_message(HumanMessage(content=question))
    response = llm.predict(long_memory)
    long_memory.add_message(AgentMessage(content=response.get_last().content))
    print(f"\nQ: {question}")
    print(f"A: {response.get_last().content}")
# Out:
# Long Memory Responses:
#
# Q: Tell me about renewable energy
# A: ## Renewable Energy
#
# Renewable energy refers to energy sources that are naturally replenished by the Earth's processes and can be harnessed for electricity generation, heating, and transportation. These sources are sustainable and emit little to no greenhouse gases, making them crucial for mitigating climate change and ensuring energy security.
#
# **Types of Renewable Energy:**
#
# * **Solar energy:** Harnesses the sun's energy using solar panels or solar thermal systems.
# * **Wind energy:** Extracts kinetic energy from the wind using wind turbines.
# * **Hydropower:** Uses flowing water to generate electricity in dams or turbines.
# * **Geothermal energy:** Extracts heat from the Earth's core for heating and electricity.
# * **Bioenergy:** Generates energy from organic materials like plants and wood.
#
#
# **Advantages of Renewable Energy:**
#
# * **Sustainable:** Renewable sources are replenished naturally, ensuring long-term energy availability.
# * **Clean:** Produces little to no greenhouse gas emissions, mitigating climate change.
# * **Cost-effective:** Costs are decreasing rapidly, making renewable energy increasingly competitive.
# * **Job creation:** Installing and maintaining renewable energy systems creates new job opportunities.
#
#
# **Disadvantages of Renewable Energy:**
#
# * **Intermittent:** Sources like solar and wind are intermittent,
#
# Q: What about solar power specifically?
# A: ## Solar Power
#
# Solar power is a renewable energy technology that harnesses the power of the sun to generate electricity.
#
# **How it works:**
#
# * Solar panels made of silicon solar cells absorb sunlight.
# * Electrons are excited by the absorbed energy, creating an electrical current.
# * The direct current (DC) generated is then converted to alternating current (AC) for use in homes and businesses.
#
# **Advantages of Solar Power:**
#
# * **Abundant and accessible:** Abundant sunlight is readily available globally.
# * **Clean and emission-free:** Produces no greenhouse gas emissions or air pollution.
# * **Cost-effective:** Costs have declined significantly in recent years.
# * **Reliable:** Technology has matured and is highly reliable.
#
#
# **Disadvantages of Solar Power:**
#
# * **Initial investment:** Installing solar panels can be expensive.
# * **Intermittent:** Output depends on sunlight availability, impacting energy generation.
# * **Storage limitations:** Limited technology for storing excess energy for periods of low sunlight.
#
#
# **Applications of Solar Power:**
#
# * **Residential:** Powering homes and appliances
# * **Commercial:** Powering businesses and industries
# * **Utility-scale:** Generating large-scale electricity for the grid
#
# Q: How do solar panels work?
# A: **Solar panels work by harnessing the power of sunlight to generate electricity.**
#
# **Step 1: Photon absorption:**
#
# * Sunlight is composed of photons, tiny bundles of energy.
# * When photons strike the silicon atoms in the solar cells, they knock out electrons.
#
#
# **Step 2: Electron flow:**
#
# * The ejected electrons are attracted to a positively charged electrode, creating a flow of electricity.
# * The movement of electrons generates direct current (DC) electricity.
#
#
# **Step 3: Conversion to AC:**
#
# * The DC electricity generated by solar panels is then converted to alternating current (AC) for use in homes and businesses.
#
#
# **Key components of a solar panel:**
#
# * **Silicon solar cells:** Absorbing sunlight and generating electrons.
# * **Metal electrodes:** Connecting the cells and facilitating electron flow.
# * **Transparent encapsulant:** Protecting the cells from the elements.
# * **Frame:** Supporting the panel and providing electrical isolation.
#
# Q: What's their efficiency?
# A: **The efficiency of solar panels refers to the percentage of sunlight that is converted into electricity.**
#
# **Typical efficiency ranges:**
#
# * **Mono-crystalline silicon:** 20-25%
# * **Polycrystalline silicon:** 15-20%
# * **Thin-film silicon:** 8-12%
#
# **Factors influencing efficiency:**
#
# * **Cell type:** Different silicon types have varying absorption efficiencies.
# * **Light intensity:** The amount of sunlight reaching the panel.
# * **Temperature:** Higher temperatures reduce efficiency.
# * **Shading:** Shadows on the panel reduce energy output.
# * **Cell quality:** Manufacturing quality and defects can impact efficiency.
#
# **Higher efficiency solar panels:**
#
# * Use advanced materials with improved light absorption.
# * Have larger surface areas to capture more sunlight.
# * Employ innovative cell designs to optimize energy capture.
#
# **Note:** The efficiency of solar panels has been steadily increasing over time and is expected to continue to improve in the future.

# %% [markdown]
#  **Compare memory contents**

# %% [markdown]
# ## **Advanced Memory Management**

# %% [markdown]
# **Create a conversation with memory management for a complex task**

# %%
# Create a conversation for complex topic discussion
conversation = SessionCacheConversation(
    system_context=SystemMessage(content="You are an AI research expert"),
    max_size=8
)

# %% [markdown]
# **Simulate deep discussion with memory tracking**

# %%
discussion_points = [
    "What is deep learning?",
    "Explain neural networks",
    "How does backpropagation work?",
    "What are activation functions?",
    "How do CNNs differ from RNNs?"
]

# %%
memory_states = []

for question in discussion_points:
    # Add question and get response
    conversation.add_message(HumanMessage(content=question))
    response = llm.predict(conversation)
    conversation.add_message(AgentMessage(content=response.get_last().content))
    
    # Track memory state
    memory_states.append({
        'question': question,
        'memory_size': len(conversation.history),
        'has_context': len(conversation.history) > 1
    })
    
    print(f"\nQ: {question}")
    print(f"A: {response.get_last().content}")
    print(f"Memory State: {memory_states[-1]}")
# Out:
# Q: What is deep learning?
# A: **Deep Learning**
#
# Deep learning is a subset of machine learning that employs artificial neural networks (ANNs) with multiple hidden layers to extract complex patterns from data. It involves training models on large volumes of data to learn representations and make accurate predictions or classifications.
#
# **Architecture:**
#
# Deep learning models typically consist of multiple interconnected layers:
#
# * **Input layer:** Receives raw data.
# * **Hidden layers:** Multiple layers that perform non-linear transformations, extracting features from the input.
# * **Output layer:** Predicts the desired outcome based on the learned features.
#
#
# **Characteristics:**
#
# * **Multiple hidden layers:** Allows for hierarchical feature extraction.
# * **Non-linear activation functions:** Introduces non-linearity, enabling the model to learn complex patterns.
# * **Large datasets:** Requires vast amounts of training data to learn meaningful representations.
# * **Computational power:** Training deep models can be computationally intensive.
#
#
# **Types of Deep Learning Models:**
#
# * **Convolutional Neural Networks (CNNs):** Suitable for image recognition and classification.
# * **Recurrent Neural Networks (RNNs):** Designed for sequential data like text or time series.
# * **Generative Adversarial Networks (GANs):** Used for image generation and data
# Memory State: {'question': 'What is deep learning?', 'memory_size': 3, 'has_context': True}
#
# Q: Explain neural networks
# A: **Neural Networks**
#
# Neural networks are computer systems inspired by biological brains. They consist of interconnected nodes or "neurons" that process and transmit information.
#
# **Architecture:**
#
# Neural networks are composed of interconnected layers:
#
# * **Input layer:** Receives raw data.
# * **Hidden layers:** Multiple layers that perform linear or non-linear transformations.
# * **Output layer:** Produces the desired output based on the learned representations.
#
#
# **How it works:**
#
# 1. **Forward pass:** Data is passed through the network layer by layer, with each node performing a weighted sum of the inputs.
# 2. **Activation:** Activation functions are applied to the summed values to introduce non-linearity.
# 3. **Backpropagation:** Errors are calculated and gradients are updated to adjust the network weights.
# 4. **Training:** The process of repeatedly feeding data through the network and adjusting weights to minimize errors.
#
#
# **Key Concepts:**
#
# * **Neurons:** Processing units that perform arithmetic operations.
# * **Weights:** Parameters that control the influence of inputs.
# * **Activations:** Functions that introduce non-linearity.
# * **Loss function:** Measure of the difference between the predicted and actual values.
# * **Optimization algorithm:** Technique for updating weights
# Memory State: {'question': 'Explain neural networks', 'memory_size': 5, 'has_context': True}
#
# Q: How does backpropagation work?
# A: **Backpropagation** is a fundamental algorithm in deep learning for training neural networks. It is the process of calculating the gradients of the loss function with respect to the network's weights and biases. This information is used to update the weights to minimize the loss.
#
# **How it works:**
#
# 1. **Forward pass:** Data is passed through the network layer by layer, and the output is produced.
# 2. **Error calculation:** The difference between the predicted and actual values is calculated as the loss.
# 3. **Backward pass:** The gradients of the loss function are calculated with respect to the weights and biases.
# 4. **Gradient update:** The weights and biases are updated in the opposite direction of the gradients to minimize the loss.
#
# **Algorithm:**
#
# - Calculate the output of the network for the given input.
# - Calculate the loss between the output and the target values.
# - Calculate the gradients of the loss function with respect to the weights and biases.
# - Update the weights and biases using the gradients.
#
# **Key features:**
#
# - **Gradients:** Provide information about how much the weights and biases should be adjusted to minimize the loss.
# - **Stochastic gradient descent:** A learning algorithm that updates the weights in the direction of the negative
# Memory State: {'question': 'How does backpropagation work?', 'memory_size': 5, 'has_context': True}
#
# Q: What are activation functions?
# A: **Activation functions** are mathematical functions that introduce non-linearity into neural networks. They are applied to the weighted sum of inputs to produce the output of a neuron.
#
# **Purpose:**
#
# - Allow neural networks to learn complex patterns from data.
# - Break the linearity of linear models.
# - Introduce non-linearity, which is essential for modeling real-world phenomena.
#
#
# **Common Activation Functions:**
#
# **1. Sigmoid function:**
# - S-shaped curve
# - Values between 0 and 1
# - Suitable for binary classification and regression
#
# **2. Tanh function:**
# - Similar to sigmoid, but outputs values between -1 and 1
# - Useful for regression and classification
#
# **3. ReLU function:**
# - Rectified linear unit
# - Values are either 0 or the input
# - Good for classification and regression
#
# **4. Leaky ReLU:**
# - Similar to ReLU, but with a small slope for negative values
# - Helps to prevent vanishing gradients
#
# **5. Softmax function:**
# - Used for multi-class classification
# - Outputs a probability distribution over the possible classes
#
# **Factors to consider when choosing an activation function:**
#
# - The nature of the problem being solved.
# - The
# Memory State: {'question': 'What are activation functions?', 'memory_size': 5, 'has_context': True}
#
# Q: How do CNNs differ from RNNs?
# A: **Convolutional Neural Networks (CNNs)** and **Recurrent Neural Networks (RNNs)** are both deep learning architectures with distinct characteristics:
#
# **CNNs (Convolutional Neural Networks)**
#
# - Convolutional layers perform feature extraction by convolving the input data with learned filters.
# - Suitable for image processing, pattern recognition, and spatial data.
# - Have a fixed spatial structure, meaning the connections between neurons are fixed and do not depend on the sequence of inputs.
#
#
# **RNNs (Recurrent Neural Networks)**
#
# - Contain loops that allow information from previous time steps to influence the current output.
# - Excellent for sequence-based tasks like text processing, time series analysis, and language translation.
# - Have a temporal structure, meaning the connections between neurons depend on the sequence of inputs.
#
#
# **Key differences:**
#
# **1. Architecture:**
# - CNNs have convolutional layers, while RNNs have recurrent connections.
# - CNNs are suitable for spatial data, while RNNs are better for sequential data.
#
# **2. Memory:**
# - CNNs do not have memory, while RNNs can retain information from previous inputs.
#
# **3. Applications:**
# - CNNs excel in image recognition, object detection, and feature extraction.
# - RNN
# Memory State: {'question': 'How do CNNs differ from RNNs?', 'memory_size': 5, 'has_context': True}

# %% [markdown]
# # **Conclusion**
# **In this notebook, we've explored:**
#
#
#
# Integration of Groq LLM with memory management
#
# Handling memory constraints in LLM conversations
#
# Comparing different memory policies with LLM responses
#
# Managing complex conversations with memory tracking
#
# Understanding how memory affects LLM context and responses
#
# **These techniques help create more effective and memory-efficient conversational AI applications.**

# %% [markdown]
# ## **NOTEBOOK METADATA**

# %%
import os
import platform
import sys
from datetime import datetime

# Display author information
author_name = "Dominion John " 
github_username = "DOMINION-JOHN1"  

print(f"Author: {author_name}")
print(f"GitHub Username: {github_username}")

# Last modified datetime (file's metadata)
notebook_file = "Notebook_04_Conversation_Memory.ipynb"
try:
    last_modified_time = os.path.getmtime(notebook_file)
    last_modified_datetime = datetime.fromtimestamp(last_modified_time)
    print(f"Last Modified: {last_modified_datetime}")
except Exception as e:
    print(f"Could not retrieve last modified datetime: {e}")

# Display platform, Python version, and Swarmauri version
print(f"Platform: {platform.system()} {platform.release()}")
print(f"Python Version: {sys.version}")

import swarmauri

try:
    version = swarmauri.__version__
except AttributeError:
    version = f"Swarmauri Version: 0.5.1"

print(f"Swarmauri Version: {version}")
# Out:
# Author: Dominion John
# GitHub Username: DOMINION-JOHN1
# Last Modified: 2024-11-04 13:33:22.996990
# Platform: Windows 11
# Python Version: 3.12.7 (tags/v3.12.7:0b05ead, Oct  1 2024, 03:06:41) [MSC v.1941 64 bit (AMD64)]
# Swarmauri Version: Swarmauri Version: 0.5.1

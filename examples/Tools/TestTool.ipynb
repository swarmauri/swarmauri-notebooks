# %% [markdown]
# # Import Dependencies

# %%
from swarmauri.standard.tools.concrete.TestTool import TestTool

# %% [markdown]
# # Instantiate TestTool

# %%
tool = TestTool()

# %% [markdown]
# # Resource of Tool

# %%
tool.resource
# Out:
# 'Tool'

# %% [markdown]
# # Calling Tool

# %%
tool('calc')
# Out:
# 'Program Opened: calc'

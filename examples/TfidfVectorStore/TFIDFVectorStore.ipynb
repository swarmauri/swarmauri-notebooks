# %% [markdown]
# # Import Dependencies

# %%
from swarmauri.standard.documents.concrete.Document import Document
from swarmauri.standard.vector_stores.concrete.TfidfVectorStore import TfidfVectorStore

# %% [markdown]
# # Instantiate Vector Store and Documents List

# %%
vs = TfidfVectorStore()
documents = [Document(content="test"),
     Document(content='test1'),
     Document(content='test2'),
     Document(content='pickle')]

# %% [markdown]
# # Add Documents

# %%
vs.add_documents(documents)

# %% [markdown]
# # Retrieve

# %%
vs.retrieve('test', top_k=1)
# Out:
# [Document(name=None, id='72541026-d688-442f-b2e3-5e43de6850d7', members=[], owner=None, host=None, resource='Document', version='0.1.0', type='Document', content='test', metadata={}, embedding=None)]

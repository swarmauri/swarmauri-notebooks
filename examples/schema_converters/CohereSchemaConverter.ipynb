# %% [markdown]
# # Import Dependencies

# %%
from swarmauri.standard.tools.concrete.AdditionTool import AdditionTool  # Using AdditionTool as the example tool to be used
from swarmauri.standard.toolkits.concrete.Toolkit import Toolkit
from swarmauri.standard.agents.concrete.ToolAgent import ToolAgent

from swarmauri.standard.schema_converters.concrete.CohereSchemaConverter import (
    CohereSchemaConverter as Schema)

# %% [markdown]
# # Initialize your ToolKit and add the tool(s)

# %%
toolkit = Toolkit()
tool = AdditionTool()
toolkit.add_tool(tool)

# %% [markdown]
# # Convert the tool(s)

# %%
result = [Schema().convert(toolkit.tools[tool]) for tool in toolkit.tools]

# %%
result
# Out:
# [{'name': 'AdditionTool',
#   'description': 'This tool has two numbers together',
#   'parameter_definitions': {'x': {'description': 'The left operand',
#     'required': True,
#     'type': 'int'},
#    'y': {'description': 'The right operand',
#     'required': True,
#     'type': 'int'}}}]
